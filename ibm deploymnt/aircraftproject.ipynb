# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_88dfd93a624d4effaa58ac78e0d640c8 = 'https://s3.us.cloud-object-storage.appdomain.cloud'
else:
    endpoint_88dfd93a624d4effaa58ac78e0d640c8 = 'https://s3.private.us.cloud-object-storage.appdomain.cloud'

client_88dfd93a624d4effaa58ac78e0d640c8 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='tcsI9S9lsYbKfp1AA4kgbwlqBuyj-ZG1aNAAaVY-r3iW',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_88dfd93a624d4effaa58ac78e0d640c8)

body = client_88dfd93a624d4effaa58ac78e0d640c8.get_object(Bucket='predictivemaintenanceaircraft-donotdelete-pr-hffnntloxwjcuj',Key='PM_train.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

dataset_train = pd.read_csv(body)
dataset_train.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18  s19    s20  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100  39.06
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100  39.00
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100  38.95
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100  38.88
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100  38.90
#
#        s21
# 0  23.4190
# 1  23.4236
# ...

# %%
body = client_88dfd93a624d4effaa58ac78e0d640c8.get_object(Bucket='predictivemaintenanceaircraft-donotdelete-pr-hffnntloxwjcuj',Key='PM_test.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

dataset_test = pd.read_csv(body)
dataset_test.head()
#dataset_test=pd.read_csv('PM_test.txt',sep=' ',header=None).drop([26,27],axis=1)

#dataset_test.columns=col_names
#print('Shape of test dataset:',dataset_train.shape)
#dataset_train.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1    0.0023    0.0003       100  518.67  643.02  1585.29  1398.21
# 1   1      2   -0.0027   -0.0003       100  518.67  641.71  1588.45  1395.42
# 2   1      3    0.0003    0.0001       100  518.67  642.46  1586.94  1401.34
# 3   1      4    0.0042    0.0000       100  518.67  642.44  1584.12  1406.42
# 4   1      5    0.0014    0.0000       100  518.67  642.51  1587.19  1401.92
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18  s19    s20  \
# 0  14.62  ...  521.72  2388.03  8125.55  8.4052  0.03  392  2388  100  38.86
# 1  14.62  ...  522.16  2388.06  8139.62  8.3803  0.03  393  2388  100  39.02
# 2  14.62  ...  521.97  2388.03  8130.10  8.4441  0.03  393  2388  100  39.08
# 3  14.62  ...  521.38  2388.05  8132.90  8.3917  0.03  391  2388  100  39.00
# 4  14.62  ...  522.15  2388.03  8129.54  8.4031  0.03  390  2388  100  38.99
#
#        s21
# 0  23.3735
# 1  23.3916
# ...

# %%
body = client_88dfd93a624d4effaa58ac78e0d640c8.get_object(Bucket='predictivemaintenanceaircraft-donotdelete-pr-hffnntloxwjcuj',Key='PM_truth.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

dataset_truth = pd.read_csv(body)
dataset_truth.head()
#pm_truth=pd.read_csv('PM_truth.txt',sep=' ',header=None).drop([1],axis=1)
dataset_truth.columns=['more']
dataset_truth['id']=dataset_truth.index+1
#_truth.head()

# %%
rul = pd.DataFrame(dataset_train.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id','max']
rul.head()
# Out:
#    id  max
# 0   1  192
# 1   2  287
# 2   3  179
# 3   4  189
# 4   5  269

# %%
dataset_truth[ 'rtf' ] = dataset_truth[ 'more' ] + rul[ 'max' ]
dataset_truth.head()
# Out:
#    more  id    rtf
# 0    98   1  290.0
# 1    69   2  356.0
# 2    82   3  261.0
# 3    91   4  280.0
# 4    93   5  362.0

# %%
dataset_truth.drop('more', axis=1, inplace=True)
dataset_test=dataset_test.merge(dataset_truth, on=['id'],how='left')
dataset_test['ttf']=dataset_test['rtf'] - dataset_test['cycle']
dataset_test.drop('rtf', axis=1, inplace=True)
dataset_test.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1    0.0023    0.0003       100  518.67  643.02  1585.29  1398.21
# 1   1      2   -0.0027   -0.0003       100  518.67  641.71  1588.45  1395.42
# 2   1      3    0.0003    0.0001       100  518.67  642.46  1586.94  1401.34
# 3   1      4    0.0042    0.0000       100  518.67  642.44  1584.12  1406.42
# 4   1      5    0.0014    0.0000       100  518.67  642.51  1587.19  1401.92
#
#       s5  ...      s13      s14     s15   s16  s17   s18  s19    s20      s21  \
# 0  14.62  ...  2388.03  8125.55  8.4052  0.03  392  2388  100  38.86  23.3735
# 1  14.62  ...  2388.06  8139.62  8.3803  0.03  393  2388  100  39.02  23.3916
# 2  14.62  ...  2388.03  8130.10  8.4441  0.03  393  2388  100  39.08  23.4166
# 3  14.62  ...  2388.05  8132.90  8.3917  0.03  391  2388  100  39.00  23.3737
# 4  14.62  ...  2388.03  8129.54  8.4031  0.03  390  2388  100  38.99  23.4130
#
#      ttf
# 0  289.0
# 1  288.0
# ...

# %%
dataset_train['ttf'] = dataset_train.groupby(['id'])['cycle'].transform(max)-dataset_train['cycle']
dataset_train.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18  s19    s20      s21  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100  39.06  23.4190
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100  39.00  23.4236
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100  38.90  23.4044
#
#    ttf
# 0  191
# 1  190
# 2  189
# ...

# %%
df_train=dataset_train.copy()
df_test=dataset_test.copy()
period=30
df_train['label_bc'] = df_train["ttf"].apply(lambda x: 1 if x<= period else 0)
df_test['label_bc'] = df_test["ttf"].apply(lambda x: 1 if x <= period else 0)
df_train.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s14     s15   s16  s17   s18  s19    s20      s21  ttf  \
# 0  14.62  ...  8138.62  8.4195  0.03  392  2388  100  39.06  23.4190  191
# 1  14.62  ...  8131.49  8.4318  0.03  392  2388  100  39.00  23.4236  190
# 2  14.62  ...  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442  189
# 3  14.62  ...  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739  188
# 4  14.62  ...  8133.80  8.4294  0.03  393  2388  100  38.90  23.4044  187
#
#    label_bc
# 0         0
# 1         0
# 2         0
# ...

# %%
df_train.drop(['ttf'],axis=1,inplace=True)
df_test.drop(['ttf'],axis=1, inplace=True)

# %%
x_train = df_train.iloc[:,:-1].values
y_train = df_train.iloc[:,-1].values
x_test = df_train.iloc[:,:-1].values
#y_test = df_train.iloc[:,-1].values

# %%
#model building

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(x_train,y_train)
# Out:
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
y_predlog=model1.predict(x_test)
accuracy_score(y_predlog, y_test )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d61b85d0b1e7> in <module>
# ----> 1 y_predlog=model1.predict(x_test)
#       2 accuracy_score(y_predlog, y_test )
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_test,y_predlog)
cm1

# %%
import joblib

# %%
#SAVE THE MODEL

# %%
joblib.dump(model,"engine_model.sav")
# Out:
# ['engine_model.sav']

# %%
x_train.shape
# Out:
# (20631, 26)

# %%
x_train[0]
# Out:
# array([ 1.00000e+00,  1.00000e+00, -7.00000e-04, -4.00000e-04,
#         1.00000e+02,  5.18670e+02,  6.41820e+02,  1.58970e+03,
#         1.40060e+03,  1.46200e+01,  2.16100e+01,  5.54360e+02,
#         2.38806e+03,  9.04619e+03,  1.30000e+00,  4.74700e+01,
#         5.21660e+02,  2.38802e+03,  8.13862e+03,  8.41950e+00,
#         3.00000e-02,  3.92000e+02,  2.38800e+03,  1.00000e+02,
#         3.90600e+01,  2.34190e+01])

# %%
from ibm_watson_machine_learning import APIClient
import json
import numpy as np

# %%
#from ibm_watson_machine_learning import APIClient 
wml_credentials={
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey":"yRrxWYCduJe9oe664g4jPMnAK7oEXdcycNCMXbaFuYov"

    
}
client = APIClient(wml_credentials)

# %%
#def guid_from_space_name(client,space_name): 
   # space=client.spaces.get_details() 
    #return(next(item for item in space['resources'] if item['entity']["name"]==space_name)['metadata']['id'])

# %%
#space_uid=guid_from_space_name(client,'models') 
#print("Space UID="+space_uid)

# %%
wml_client = APIClient(wml_credentials)
wml_client.spaces.list()
# Out:
# Note: 'limit' is not provided. Only first 50 records will be displayed if the number of records exceed 50
# ------------------------------------  ------  ------------------------
# ID                                    NAME    CREATED
# 66c5a8cb-af2e-45f6-863d-7ec5898ba772  models  2021-10-29T08:27:16.458Z
# ------------------------------------  ------  ------------------------

# %%
SPACE_ID="66c5a8cb-af2e-45f6-863d-7ec5898ba772"

# %%
wml_client.set.default_space(SPACE_ID)
# Out:
# 'SUCCESS'

# %%
wml_client.software_specifications.list()
# Out:
# -----------------------------  ------------------------------------  ----
# NAME                           ASSET_ID                              TYPE
# default_py3.6                  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# pytorch-onnx_1.3-py3.7-edt     069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6        09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12     09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# ai-function_0.1-py3.6          0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                     0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod   1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6              10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# tensorflow_1.15-py3.6-ddl      111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# scikit-learn_0.22-py3.6        154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base
# default_r3.6                   1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base
# ...

# %%
#save and deploy

# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.2'

# %%
MODEL_NAME = 'EngineFailure'
DEPLOYMENT_NAME = 'models'
ENGINE_FAILURE=model1

# %%
# Set Python Version
software_spec_uid = wml_client.software_specifications.get_id_by_name('default_py3.8')

# Setup model meta
model_props = {
    wml_client.repository.ModelMetaNames.NAME:  'EngineFailure', 
    wml_client.repository.ModelMetaNames.TYPE: 'scikit-learn_0.23', 
    wml_client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid 
}

# %%
#model_details= client.repository.store_model-model1,meta_props={
#client.repository.ModelMetaNames.Name:"Aircraft_engine",
#client.repository.ModelMetaNames.Type:" 'scikit-learn_0.23'",
#client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid 
#}
#model_id=client.repository.get_model_uid(model_details)

# %%
#Save model
model_details = wml_client.repository.store_model(
    model=ENGINE_FAILURE, 
    meta_props=model_props, 
    training_data=x_train, 
    training_target=y_train
)

# %%
model_details
# Out:
# {'entity': {'label_column': 'l1',
#   'software_spec': {'id': 'ab9e1b80-f2ce-592c-a7d2-4f2344f77194',
#    'name': 'default_py3.8'},
#   'training_data_references': [{'connection': {'access_key_id': 'not_applicable',
#      'endpoint_url': 'not_applicable',
#      'secret_access_key': 'not_applicable'},
#     'id': '1',
#     'location': {},
#     'schema': {'fields': [{'name': 'f0', 'type': 'float'},
#       {'name': 'f1', 'type': 'float'},
#       {'name': 'f2', 'type': 'float'},
#       {'name': 'f3', 'type': 'float'},
#       {'name': 'f4', 'type': 'float'},
#       {'name': 'f5', 'type': 'float'},
#       {'name': 'f6', 'type': 'float'},
#       {'name': 'f7', 'type': 'float'},
#       {'name': 'f8', 'type': 'float'},
#       {'name': 'f9', 'type': 'float'},
#       {'name': 'f10', 'type': 'float'},
#       {'name': 'f11', 'type': 'float'},
#       {'name': 'f12', 'type': 'float'},
#       {'name': 'f13', 'type': 'float'},
#       {'name': 'f14', 'type': 'float'},
# ...

# %%
model_uid = wml_client.repository.get_model_uid(model_details); model_uid
# Out:
# 'e87b6cf2-c167-4d7c-b33f-374ffa33c3d6'

# %%
wml_client.connections.list_datasource_types()
# Out:
# -------------------------  ------------------------------------  --------  ------
# NAME                       DATASOURCE_ID                         TYPE      STATUS
# informix                   029e5d1c-ba73-4b09-b742-14c3a39b6cf9  database  active
# postgresql-ibmcloud        048ed1bf-516c-46f0-ae90-fa3349d8bc1c  database  active
# googlecloudstorage         05b7f0ea-6ae4-45e2-a455-cc280f110825  file      active
# impala                     05c58384-862e-4597-b19a-c71ea7e760bc  database  active
# salesforce                 06847b16-07b4-4415-a924-c63d11a17aa1  database  active
# datastax-ibmcloud          0bd5946b-6fcb-4253-bf76-48b362d24a89  database  active
# cosmos                     0c431748-2572-11ea-978f-2e728ce88125  file      active
# odbc-datastage             0ca92c3d-0e46-3b42-a573-77958d53c9be  database  active
# mysql-compose              0cd4b64c-b485-47ed-a8c4-329c25412de3  database  active
# ...

# %%
# Set meta
deployment_props = {
    wml_client.deployments.ConfigurationMetaNames.NAME: 'EngineFailure',
  #  wml_client.deployments.ConfigurationMetaNames.ONLINE: 'EngineFailure'
}

# %%
# Out:
# {"trace":"1jthj4o1fjd5i","errors":[{"code":"space_lacks_compute","message":"Space: 66c5a8cb-af2e-45f6-863d-7ec5898ba772 is not associated with a WML instance which is mandatory for create_deployment operation"}]}
#
#
# --------------------------
# Deployment creation failed
# --------------------------
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# <ipython-input-190-03d683cd964c> in <module>
#       1 # Deploy
# ----> 2 deployment = wml_client.deployments.create(
#       3     artifact_uid='1f21659d-87a3-4a25-95ff-ac4abd74058e',
#       4     meta_props=deployment_props
#       5 )
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/ibm_watson_machine_learning/deployments.py in create(self, artifact_uid, meta_props, rev_id, **kwargs)
#     273                 print(reason)
#     274                 print_text_header_h2(error_msg)
# ...

# %%
# Out:
# '1f21659d-87a3-4a25-95ff-ac4abd74058e'
